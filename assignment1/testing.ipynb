# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np

# %%
def conv2d_3x3(filters):
    conv = layers.Conv2D(
        filters, kernel_size=(3, 3), activation='relu', padding='same'
    )
    return conv

# %%
def copy_crop(image, filters):
    c = conv2d_3x3(filters)(image)
    c = conv2d_3x3(filters)(c)
    p = max_pool()(c)

    return c, p

# %%
input_shape = (32, 256, 256)

x = np.arange(np.prod(input_shape)).reshape(input_shape)
x
# Out:
# array([[[      0,       1,       2, ...,     253,     254,     255],
#         [    256,     257,     258, ...,     509,     510,     511],
#         [    512,     513,     514, ...,     765,     766,     767],
#         ...,
#         [  64768,   64769,   64770, ...,   65021,   65022,   65023],
#         [  65024,   65025,   65026, ...,   65277,   65278,   65279],
#         [  65280,   65281,   65282, ...,   65533,   65534,   65535]],
#
#        [[  65536,   65537,   65538, ...,   65789,   65790,   65791],
#         [  65792,   65793,   65794, ...,   66045,   66046,   66047],
#         [  66048,   66049,   66050, ...,   66301,   66302,   66303],
#         ...,
#         [ 130304,  130305,  130306, ...,  130557,  130558,  130559],
#         [ 130560,  130561,  130562, ...,  130813,  130814,  130815],
#         [ 130816,  130817,  130818, ...,  131069,  131070,  131071]],
#
#        [[ 131072,  131073,  131074, ...,  131325,  131326,  131327],
#         [ 131328,  131329,  131330, ...,  131581,  131582,  131583],
#         [ 131584,  131585,  131586, ...,  131837,  131838,  131839],
#         ...,
#         [ 195840,  195841,  195842, ...,  196093,  196094,  196095],
#         [ 196096,  196097,  196098, ...,  196349,  196350,  196351],
#         [ 196352,  196353,  196354, ...,  196605,  196606,  196607]],
#
#        ...,
#
#        [[1900544, 1900545, 1900546, ..., 1900797, 1900798, 1900799],
#         [1900800, 1900801, 1900802, ..., 1901053, 1901054, 1901055],
#         [1901056, 1901057, 1901058, ..., 1901309, 1901310, 1901311],
#         ...,
#         [1965312, 1965313, 1965314, ..., 1965565, 1965566, 1965567],
#         [1965568, 1965569, 1965570, ..., 1965821, 1965822, 1965823],
#         [1965824, 1965825, 1965826, ..., 1966077, 1966078, 1966079]],
#
#        [[1966080, 1966081, 1966082, ..., 1966333, 1966334, 1966335],
#         [1966336, 1966337, 1966338, ..., 1966589, 1966590, 1966591],
#         [1966592, 1966593, 1966594, ..., 1966845, 1966846, 1966847],
#         ...,
#         [2030848, 2030849, 2030850, ..., 2031101, 2031102, 2031103],
#         [2031104, 2031105, 2031106, ..., 2031357, 2031358, 2031359],
#         [2031360, 2031361, 2031362, ..., 2031613, 2031614, 2031615]],
#
#        [[2031616, 2031617, 2031618, ..., 2031869, 2031870, 2031871],
#         [2031872, 2031873, 2031874, ..., 2032125, 2032126, 2032127],
#         [2032128, 2032129, 2032130, ..., 2032381, 2032382, 2032383],
#         ...,
#         [2096384, 2096385, 2096386, ..., 2096637, 2096638, 2096639],
#         [2096640, 2096641, 2096642, ..., 2096893, 2096894, 2096895],
#         [2096896, 2096897, 2096898, ..., 2097149, 2097150, 2097151]]])
